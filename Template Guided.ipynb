# %% [markdown]
# ## <div align="center"> TUGAS LAB IS388 Data Analysis </div>
# ## <div align="center"> WEEK [09]: [Tugas Pertemuan 9]</div>
# #### <div align="center"> Semester Ganjil 2025/2026 </div>
# ---

# %%
import datetime
import uuid

studentName = "Steve Yinda, Fransisca Valerie Roberts, Felicio Balamitta Putra, Alexander William"
studentNIM = "110356, 108982, 108859, 108937"
studentClass = "IS388-E"

# %%
myDate = datetime.datetime.now()
myDevice = str(uuid.uuid1())

print("Name: \t\t{}".format(studentName))
print("NIM: \t\t{}".format(studentNIM))
print("NIM: \t\t{}".format(studentClass))
print("Start: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Steve Yinda, Fransisca Valerie Roberts, Felicio Balamitta Putra, Alexander William
# NIM: 		110356, 108982, 108859, 108937
# NIM: 		IS388-E
# Start: 		2025-11-03 13:35:21.473959
# Device ID: 	f1de311c-b8b9-11f0-b748-0242ac1c000c

# %% [markdown]
# ---

# %% [markdown]
# ## <div align="center"> Guided Lab </div>

# %% [markdown]
# ### Enter Guided Lab Code Here:

# %% [markdown]
# ----

# %% [markdown]
# ## <div align="center"> Conclusion </div>

# %% [markdown]
# ### Enter Your Conclusion Here:

# %% [markdown]
# ----

# %%
studentName2 = "Nama2"
studentNIM2 = "NIM2"
studentClass2 = "Class2"

# %%
print("Name: \t\t{}".format(studentName2))
print("NIM: \t\t{}".format(studentNIM2))
print("NIM: \t\t{}".format(studentClass2))
print("End: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Nama2
# NIM: 		NIM2
# NIM: 		Class2
# End: 		2024-08-20 10:02:04.030425
# Device ID: 	93dd427e-5ea0-11ef-80df-0045e2d68e9e

# %% [markdown]
# ----

# %% [markdown]
# ## <div align="center"> Reference </div>

# %% [markdown]
# ### Input Your Reference Here  (Jika ada):

# %% [markdown]
# ----
